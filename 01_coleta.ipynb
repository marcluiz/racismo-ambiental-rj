# %% [markdown]
# <a href="https://colab.research.google.com/github/marcluiz/racismo-ambiental-rj/blob/main/01_coleta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
base = "/content/drive/MyDrive/Grupo de Pesquisa - Racismo Ambiental RJ/"
os.listdir(base)
# Out:
# ['01_Artigos_e_Referencial_Teorico ',
#  '02_Dados_Brutos_e_Insumos ',
#  '03_Dados_Tratados ',
#  '04_Dados_Finais_e_Indicadores ',
#  '05_Scripts_e_Codigos ',
#  '06_Documentacao ',
#  '07_Saidas_Mapas_e_Graficos ']
